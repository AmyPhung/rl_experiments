# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("NavEnvV1.0/training_stats.csv")
df.head()
# Out:
#    Unnamed: 0  Episode Lengths  Episode Rewards
# 0           0             82.0      -106.311681
# 1           1            144.0      -111.332975
# 2           2            501.0       -95.427087
# 3           3            165.0      1001.223371
# 4           4             41.0       999.234009

# %%
smoothing_window = 100

# %%
plt.plot(df["Episode Rewards"].rolling(smoothing_window, min_periods=smoothing_window).mean())

# %%
df = pd.read_csv("NavEnvV2.0/training_stats.csv")
df.head()
smoothing_window = 100
plt.plot(df["Episode Rewards"].rolling(smoothing_window, min_periods=smoothing_window).mean())
